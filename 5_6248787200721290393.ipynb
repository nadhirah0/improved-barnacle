# %%
import pandas as pd

dfclean = pd.read_csv('clean_df3.csv')

link = 'https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DA0101EN/automobileEDA.csv'
df = pd.read_csv(link)
df.head(10)

dfclean.head()
# Out:
#    Unnamed: 0  symboling  normalized-losses         make aspiration  \
# 0           0          3                122  alfa-romero        std
# 1           1          1                122  alfa-romero        std
# 2           2          2                164         audi        std
# 3           3          2                164         audi        std
# 4           4          2                122         audi        std
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0          two  convertible          rwd           front        88.6  ...
# 1          two    hatchback          rwd           front        94.5  ...
# 2         four        sedan          fwd           front        99.8  ...
# 3         four        sedan          4wd           front        99.4  ...
# 4          two        sedan          fwd           front        99.8  ...
#
#    city-L/100km  highway-L/100km  fuel-type-diesel  fuel-type-gas  \
# ...

# %%
df.corr()
# Out:
#                    symboling  normalized-losses  wheel-base    length  \
# symboling           1.000000           0.466264   -0.535987 -0.365404
# normalized-losses   0.466264           1.000000   -0.056661  0.019424
# wheel-base         -0.535987          -0.056661    1.000000  0.876024
# length             -0.365404           0.019424    0.876024  1.000000
# width              -0.242423           0.086802    0.814507  0.857170
# height             -0.550160          -0.373737    0.590742  0.492063
# curb-weight        -0.233118           0.099404    0.782097  0.880665
# engine-size        -0.110581           0.112360    0.572027  0.685025
# bore               -0.140019          -0.029862    0.493244  0.608971
# stroke             -0.008245           0.055563    0.158502  0.124139
# compression-ratio  -0.182196          -0.114713    0.250313  0.159733
# horsepower          0.075819           0.217299    0.371147  0.579821
# ...

# %%
df[['price', 'engine-size']].corr()
# Out:
#                 price  engine-size
# price        1.000000     0.872335
# engine-size  0.872335     1.000000

# %%
# Pearson Method
from scipy import stats

pearson_coef , p_value = stats.pearsonr(df['engine-size'], df['price'])
print ('Pearson Correlation is', pearson_coef, 'P_Value is', p_value)
# Out:
# Pearson Correlation is 0.8723351674455185 P_Value is 9.265491622198389e-64

# %%
pearson_coef , p_value = stats.pearsonr(df['horsepower'], df['price'])
print ('Pearson Correlation is', pearson_coef, 'P_Value is', p_value)
# Out:
# Pearson Correlation is 0.809574567003656 P_Value is 6.369057428259557e-48

# %%
pearson_coef , p_value = stats.pearsonr(df['symboling'], df['price'])
print ('Pearson Correlation is', pearson_coef, 'P_Value is', p_value)
# Out:
# Pearson Correlation is -0.08239118716962358 P_Value is 0.2449148765716521

# %%
df[['price', 'horsepower', 'stroke', 'bore', 'city-L/100km', 'width', 'length' ]].corr()
# Out:
#                  price  horsepower    stroke      bore  city-L/100km  \
# price         1.000000    0.809575  0.082310  0.543155      0.789898
# horsepower    0.809575    1.000000  0.098462  0.566936      0.889488
# stroke        0.082310    0.098462  1.000000 -0.055390      0.037300
# bore          0.543155    0.566936 -0.055390  1.000000      0.554610
# city-L/100km  0.789898    0.889488  0.037300  0.554610      1.000000
# width         0.751265    0.615077  0.188829  0.544885      0.673363
# length        0.690628    0.579821  0.124139  0.608971      0.657373
#
#                  width    length
# price         0.751265  0.690628
# horsepower    0.615077  0.579821
# stroke        0.188829  0.124139
# bore          0.544885  0.608971
# city-L/100km  0.673363  0.657373
# width         1.000000  0.857170
# length        0.857170  1.000000

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
sns.regplot(x='engine-size', y='price', data=df)
# Out:
# <AxesSubplot:xlabel='engine-size', ylabel='price'>

# %%
#sns.regplot(x='city-L/100km', y='price', data=df)

# %%
#sns.regplot(x='stroke', y='price', data=df)

# %%
sns.boxplot(x='drive-wheels', y='price', data=df)
# Out:
# <AxesSubplot:xlabel='drive-wheels', ylabel='price'>

# %%
sns.boxplot(x='make', y='price', data=df)
# Out:
# <AxesSubplot:xlabel='make', ylabel='price'>

# %%
sns.boxplot(x='aspiration', y='price', data=df)
# Out:
# <AxesSubplot:xlabel='aspiration', ylabel='price'>

# %%
sns.boxplot(x='num-of-doors', y='price', data=df)
# Out:
# <AxesSubplot:xlabel='num-of-doors', ylabel='price'>

# %%
sns.boxplot(x='engine-location', y='price', data=df)
# Out:
# <AxesSubplot:xlabel='engine-location', ylabel='price'>

# %%
# Group By

df2 = df[['drive-wheels' , 'body-style' , 'price']]

df2_group = df2.groupby(['drive-wheels' , 'body-style'], as_index=False).mean()

df2_group
# Out:
#    drive-wheels   body-style         price
# 0           4wd    hatchback   7603.000000
# 1           4wd        sedan  12647.333333
# 2           4wd        wagon   9095.750000
# 3           fwd  convertible  11595.000000
# 4           fwd      hardtop   8249.000000
# 5           fwd    hatchback   8396.387755
# 6           fwd        sedan   9811.800000
# 7           fwd        wagon   9997.333333
# 8           rwd  convertible  23949.600000
# 9           rwd      hardtop  24202.714286
# 10          rwd    hatchback  14337.777778
# 11          rwd        sedan  21711.833333
# 12          rwd        wagon  16994.222222

# %%
pivot2 = df2_group.pivot(index='drive-wheels' , columns='body-style')

pivot2
# Out:
#                    price                                            \
# body-style   convertible       hardtop     hatchback         sedan
# drive-wheels
# 4wd                  NaN           NaN   7603.000000  12647.333333
# fwd              11595.0   8249.000000   8396.387755   9811.800000
# rwd              23949.6  24202.714286  14337.777778  21711.833333
#
#
# body-style           wagon
# drive-wheels
# 4wd            9095.750000
# fwd            9997.333333
# rwd           16994.222222

# %%
df2 = df[['drive-wheels' , 'body-style' , 'price']]

df2_group = df2.groupby(['drive-wheels' , 'body-style'], as_index=True).mean()

df2_group
# Out:
#                                  price
# drive-wheels body-style
# 4wd          hatchback     7603.000000
#              sedan        12647.333333
#              wagon         9095.750000
# fwd          convertible  11595.000000
#              hardtop       8249.000000
#              hatchback     8396.387755
#              sedan         9811.800000
#              wagon         9997.333333
# rwd          convertible  23949.600000
#              hardtop      24202.714286
#              hatchback    14337.777778
#              sedan        21711.833333
#              wagon        16994.222222

# %%
df3 = df[['drive-wheels' , 'num-of-doors' , 'price']]

df3_group = df3.groupby(['drive-wheels' , 'num-of-doors'], as_index=False).mean()

df3_group
# Out:
#   drive-wheels num-of-doors         price
# 0          4wd         four  10617.857143
# 1          4wd          two   7603.000000
# 2          fwd         four   9789.072464
# 3          fwd          two   8478.326531
# 4          rwd         four  20577.000000
# 5          rwd          two  18869.944444

# %%
pivot3 = df3_group.pivot(index='drive-wheels' , columns='num-of-doors')

pivot3
# Out:
#                      price
# num-of-doors          four           two
# drive-wheels
# 4wd           10617.857143   7603.000000
# fwd            9789.072464   8478.326531
# rwd           20577.000000  18869.944444

# %%
import numpy as np


fig, ax = plt.subplots()
im = ax.pcolor(pivot2, cmap='RdBu')

#label names
row_labels = pivot2.columns.levels[1]
col_labels = pivot2.index

#move ticks and labels to the center
ax.set_xticks(np.arange(pivot2.shape[1]) + 0.5, minor=False)
ax.set_yticks(np.arange(pivot2.shape[0]) + 0.5, minor=False)

#insert labels
ax.set_xticklabels(row_labels, minor=False)
ax.set_yticklabels(col_labels, minor=False)

#rotate label if too long
plt.xticks(rotation=90)

fig.colorbar(im)
plt.show()

# %%
#import numpy as np


fig, ax = plt.subplots()
im = ax.pcolor(pivot3, cmap='RdBu')

#label names
row_labels = pivot3.columns.levels[1]
col_labels = pivot3.index

#move ticks and labels to the center
ax.set_xticks(np.arange(pivot3.shape[1]) + 0.5, minor=False)
ax.set_yticks(np.arange(pivot3.shape[0]) + 0.5, minor=False)

#insert labels
ax.set_xticklabels(row_labels, minor=False)
ax.set_yticklabels(col_labels, minor=False)

#rotate label if too long
plt.xticks(rotation=90)

fig.colorbar(im)
plt.show()
